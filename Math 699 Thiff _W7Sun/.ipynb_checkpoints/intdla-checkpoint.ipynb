# %%
#W9M 3/19

#INTDLA   Simulate internal diffusion-limited aggregation.
#   INTDLA(N) simulates an internal DLA process with N particles.
#   (If unspecified N defaults to 10000.)

#   G = INTDLA(N) also returns the final occupation grid.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
def intdla(Npart=1000):
    drift = np.array([0,0])
    Ngrid = math.ceil(1.2*math.sqrt(Npart))
    
    grid0 = Ngrid+1
    grid = np.zeros(shape=(2*Ngrid+1,2*Ngrid+1))

    for i in range(1, Npart+1):
        X = np.array([0,0])
        while 1:
            r = np.random.randint(3, size=2)
            
                
            X = X + (r - 1) + drift
            
            
            if not grid[X[0]+grid0, X[1]+grid0]:
                grid[X[0] + grid0, X[1] + grid0] = 1
                break
        if not i%100:
            print("particle {0}".format(i))
            plt.imshow(grid, extent=[-Ngrid, Ngrid, -Ngrid, Ngrid])
            plt.show()
    plt.imshow(grid, extent=[-Ngrid.Ngrid, -Ngrid, Ngrid])
    plt.show()

if __name__=='__main__':
    intdla()
# Out:
# particle 100
# particle 200
# particle 300
# particle 400
# particle 500
# particle 600
# particle 700
# particle 800
# particle 900
# particle 1000
# particle 1100
# particle 1200
# particle 1300
# particle 1400
# particle 1500
# particle 1600
# particle 1700
# particle 1800
# particle 1900
# particle 2000
# particle 2100
# particle 2200
# particle 2300
# particle 2400
# particle 2500
# particle 2600
# particle 2700
# particle 2800
# particle 2900
# particle 3000
# particle 3100
# particle 3200
# particle 3300
# particle 3400
# particle 3500
# particle 3600
# particle 3700
# particle 3800
# particle 3900
# particle 4000
# particle 4100
# particle 4200
# particle 4300
# particle 4400
# particle 4500
# particle 4600
# particle 4700
# particle 4800
# particle 4900
# particle 5000
# particle 5100
# particle 5200
# particle 5300
# particle 5400
# particle 5500
# particle 5600
# particle 5700
# particle 5800
# particle 5900
# particle 6000
# particle 6100
# particle 6200
# particle 6300
# particle 6400
# particle 6500
# particle 6600
# particle 6700
# particle 6800
# particle 6900
# particle 7000
# particle 7100
# particle 7200
# particle 7300
# particle 7400
# particle 7500
# particle 7600
# particle 7700
# particle 7800
# particle 7900
# particle 8000
# particle 8100
# particle 8200
# particle 8300
# particle 8400
# particle 8500
# particle 8600
# particle 8700
# particle 8800
# particle 8900
# particle 9000
# particle 9100
# particle 9200
# particle 9300
# particle 9400
# particle 9500
# particle 9600
# particle 9700
# particle 9800
# particle 9900
# particle 10000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2e3f6d01613a> in <module>()
#      28
#      29 if __name__=='__main__':
# ---> 30     intdla()
#      31
#
# <ipython-input-1-2e3f6d01613a> in intdla(Npart)
#      24             plt.imshow(grid, extent=[-Ngrid, Ngrid, -Ngrid, Ngrid])
#      25             plt.show()
# ---> 26     plt.imshow(grid, extent=[-Ngrid.Ngrid, -Ngrid, Ngrid])
#      27     plt.show()
#      28
#
# AttributeError: 'int' object has no attribute 'Ngrid'
